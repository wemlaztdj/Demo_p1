# %% [markdown]
# # Project1

# %% [markdown]
# ## Step 1
# Dependencies and Setup

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests

from scipy.stats import linregress

# from api_keys import geoapify_key

# %%
# Load the CSV file
df=pd.read_csv("./Resources/Kaggle/Student Loan Debt by School 2020-2021.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42740 entries, 0 to 42739
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  42740 non-null  int64
#  1   OPE ID                 42740 non-null  int64
#  2   School                 42740 non-null  object
#  3   City                   33650 non-null  object
#  4   State                  40700 non-null  object
#  5   Zip Code               33650 non-null  float64
#  6   School Type            42740 non-null  object
#  7   Loan Type              42740 non-null  object
#  8   Recipients             42740 non-null  float64
#  9   # of Loans Originated  42740 non-null  float64
#  10  $ of Loans Originated  42740 non-null  float64
#  11  # of Disbursements     42740 non-null  float64
#  12  $ of Disbursements     42740 non-null  float64
# dtypes: float64(6), int64(2), object(5)
# memory usage: 4.2+ MB

# %%
# Change data type and rename columns
df['Zip Code'] = df['Zip Code'].fillna(-1).astype(int).astype(str).replace('-1', 'NaN')
df['Recipients'] = df['Recipients'].astype(int)
df['# of Loans Originated'] = df['# of Loans Originated'].astype(int)
df['# of Disbursements'] = df['# of Disbursements'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42740 entries, 0 to 42739
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  42740 non-null  int64
#  1   OPE ID                 42740 non-null  int64
#  2   School                 42740 non-null  object
#  3   City                   33650 non-null  object
#  4   State                  40700 non-null  object
#  5   Zip Code               42740 non-null  object
#  6   School Type            42740 non-null  object
#  7   Loan Type              42740 non-null  object
#  8   Recipients             42740 non-null  int32
#  9   # of Loans Originated  42740 non-null  int32
#  10  $ of Loans Originated  42740 non-null  float64
#  11  # of Disbursements     42740 non-null  int32
#  12  $ of Disbursements     42740 non-null  float64
# dtypes: float64(2), int32(3), int64(2), object(6)
# memory usage: 3.8+ MB

# %%
df.head(10)
# Out:
#    index  OPE ID                                   School          City State  \
# 0      0    1051                    UNIVERSITY OF ALABAMA    TUSCALOOSA    AL
# 1      1    1052      UNIVERSITY OF ALABAMA AT BIRMINGHAM    BIRMINGHAM    AL
# 2      2    1009                        AUBURN UNIVERSITY        AUBURN    AL
# 3      3    1057              UNIVERSITY OF SOUTH ALABAMA        MOBILE    AL
# 4      4    1047                          TROY UNIVERSITY          TROY    AL
# 5      5    1036                       SAMFORD UNIVERSITY    BIRMINGHAM    AL
# 6      6    1024               UNIVERSITY OF WEST ALABAMA    LIVINGSTON    AL
# 7      7   42267  ALABAMA COLLEGE OF OSTEOPATHIC MEDICINE        DOTHAN    AL
# 8      8    1020            JACKSONVILLE STATE UNIVERSITY  JACKSONVILLE    AL
# 9      9    1050                      TUSKEGEE UNIVERSITY      TUSKEGEE    AL
#
#   Zip Code        School Type   Loan Type  Recipients  # of Loans Originated  \
# ...

# %%
df.describe()
# Out:
#               index        OPE ID     Recipients  # of Loans Originated  \
# count  42740.000000  42740.000000   42740.000000           42740.000000
# mean   21369.500000  16201.447824    3798.421385            3909.581844
# std    12338.119589  15479.494190   16547.929427           17095.803201
# min        0.000000   1002.000000       0.000000               0.000000
# 25%    10684.750000   2848.000000       6.000000               7.000000
# 50%    21369.500000   8447.500000     130.000000             132.000000
# 75%    32054.250000  30837.000000    1287.000000            1318.250000
# max    42739.000000  42933.000000  776959.000000          798927.000000
#
#        $ of Loans Originated  # of Disbursements  $ of Disbursements
# count           4.274000e+04        42740.000000        4.274000e+04
# mean            3.379861e+07         3974.820660        1.694132e+07
# std             1.666734e+08        17393.746307        8.551740e+07
# ...

# %% [markdown]
# ## Step 2
# ### Ask the questions

# %% [markdown]
# State, What is the breakdown of number of collages in each state?

# %% [markdown]
# State, What is the breakdown of recipients of Student Loans by State (by quantity and by $)?

# %% [markdown]
# State, What states have the most (public schools? Private schools?) recipients?

# %% [markdown]
# State, What are the top 10 states with the most student loans taken out in?

# %% [markdown]
# Geographic, How does the average student loan vary by zip code?

# %% [markdown]
# Geographic, Are there trends based on geographic region or type of school?

# %% [markdown]
# Loan Type, What is the breakdown of type of student loan  (subsidized, unsubsidized, grad plus, parent plus, etc.)?

# %% [markdown]
# School Type, What is the breakdown of student loan quantity/$ by school type (for profit, non-profit, public, etc.)?

# %% [markdown]
# VS, What is the breakdown in disbursements versus loan origination $ amounts?

# %% [markdown]
# VS, Which schools have the highest disparity between loans originated and loans disbursed?
